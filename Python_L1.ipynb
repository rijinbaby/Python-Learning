# %% [markdown]
# <a href="https://colab.research.google.com/github/rijinbaby/Python-Learning/blob/main/Python_L1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Variable
x=2
x
# Out:
# 2

# %%
type(x)
# Out:
# int

# %%
#float / double
y=2.5
type(y)
# Out:
# float
